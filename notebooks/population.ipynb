# %%
import matplotlib.pyplot as plt
import pandas
import os, sys
import openai
from tenacity import (retry, stop_after_attempt, wait_random_exponential)
import tiktoken
# Out:
# hello world

# %%
openai.api_key = "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"

@retry(wait=wait_random_exponential(min=60, max=70), stop=stop_after_attempt(6))
def completion_with_backoff(**kwargs):
    return openai.ChatCompletion.create(**kwargs)

# %%
# 这个是强调先后修提示
system_content = '''You are a helpful assistant that 
                 extract knowledge points and the concept prerequisite relations between knowledge points from contents below,
                 returning in the form of json. 
                 the value of "en" should be the english translation of the "title".
                 the value of "type" should represent relationship between "source" to "target" in 'Communication Theory' area.
                 all values are better to be in Chinese apart from "en".
                 {
                    "knowledge_points": [{"title": "", "en": ""},{"title": "",  "en": ""}, ...],
                    "relations": [{"source": "", "target": "", "type": ""}, {"source": "", "target": "", "type": ""}, ...]
                 }
                 '''
user_content = ""

# %%
# 不强调先后修
system_content = '''You are a helpful assistant that 
                 extract knowledge points and relations between knowledge points from contents below,
                 returning in the form of json. 
                 the value of "en" should be the english translation of the "title".
                 the value of "type" should represent relationship between "source" to "target" in 'Communication Theory' area.
                 all values are better to be in Chinese apart from "en".
                 {
                    "knowledge_points": [{"title": "", "en": ""},{"title": "",  "en": ""}, ...],
                    "relations": [{"source": "", "target": "", "type": ""}, {"source": "", "target": "", "type": ""}, ...]
                 }
                 '''
user_content = ""

# %%
# 读取全部文件并且分节
print(os.path.abspath(os.curdir))
with open(r"../data/通原全部.txt", 'r', encoding='utf-8') as f:
    content_lines = f.readlines() # 这个是因为没有换行符，所以读取的时候就是一行
    content_lines = content_lines[0].split("\\n") #
    print(len(content_lines))

lines=[]
temp_line=''
for line in content_lines:
    if len(temp_line)<2400:
        temp_line=temp_line+'\n'+line
    else:
        lines.append(temp_line)
        temp_line=''
lines.append(temp_line) # 添加最后一行没有到3300的
print(len(lines))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 读取全部文件并且分节
# ----> 2 print(os.path.abspath(os.curdir))
#       3 with open(r"../data/通原全部.txt", 'r', encoding='utf-8') as f:
#       4     content_lines = f.readlines()
#
# NameError: name 'os' is not defined

# %%
# 初步计算token的长度
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    num_tokens = len(encoding.encode(string))
    return num_tokens

num_tokens_from_string("tiktoken is great!", "gpt-3.5-turbo")
# 测试看看有没有超越token

for i in lines:
    if num_tokens_from_string(i, "gpt-3.5-turbo")+num_tokens_from_string(system_content, "gpt-3.5-turbo") >3500:
        print(num_tokens_from_string(i, "gpt-3.5-turbo")+num_tokens_from_string(system_content, "gpt-3.5-turbo"))
# Out:
# 3501
# 3654
# 3516

# %%
# 读取全部文件并且分节
print(os.path.abspath(os.curdir))
with open(r"../data/通信原理全部.txt", 'r', encoding='utf-8') as f:
    content_lines = f.readlines()
    # content_lines = content_lines[0].split('\n') #
    print(len(content_lines))

lines=[]
temp_line=''
for line in content_lines:
    if len(temp_line)<2400:
        temp_line=temp_line+'\n'+line
    else:
        lines.append(temp_line)
        temp_line=''
lines.append(temp_line) # 添加最后一行没有到3300的
print(len(lines))
# Out:
# /workspaces/codespaces-jupyter/notebooks
# 9437
# 130

# %%
# 我想找出lines中的元素中哪个包含了 线性调制理想相干解调
for i in lines:
    if "AM理想包络检波" in i:
        print(i)
        break
# Out:
# 　　本书系四位作者多年来从事通信与信息学科本科生和研究生的教学与科研实践的总结\n按认识论规律由概念的建立给出定量分析,且注重理论联系实际\n在介绍基本理论的基础上,力求体现近年来国内外通信技术的发展\n
#
# 　　为帮助读者掌握通信的基本原理及分析方法,提高运算能力,书中列举了许多例题,并附有大量习题及部分习题答案\n习题中包含历年来学生作业、本科试题及考研试题的精选\n
#
# 　　全书共十一章,第一章绪论,从通信发展简史及展望引导出通信的基本概念与通信系统及通信网的基本构成\n第二章确定信号分析,第三章随机过程,这两章是分析通信系统的数学工具,如果读者已有先修基础,可将其作为复习内容\n第四章模拟通信系统,阐述目前正在应用的各种模拟调制方式的基本原理及其性能分析\n第五章至第十章阐述数字通信系统的基本理论\n第五章数字信号的基带传输,第六章数字信号的频带传输,这两章是数字通信传输系统的基本理论\n第七章信源和信源编码,第八章信道和信道容量,第九章信道差错控制编码,这三章是仙农信息论的基本理论\n第十章阐述正交编码与伪随机序列的基本原理及其应用\n第十一章介绍通信网的基本原理,阐述交换的基本原理及信令和协议的基本概念\n全书分为上、下两册,一至六章为上册,七至十一章为下册\n
#
# 　　本书可用作高等学校本科生通信工程专业、电子与信息专业以及其他相近专业的专业基础课的教科书\n全书可在大学三年级分两学期授课\n
#
# 　　本书也可作为通信工程技术人员的参考书\n读者欲仅限于掌握模拟通信,则只需阅读前四章；若仅限于掌握数字通信,不必阅读第四章\n
#
# 　　全书由周炯槃院士主编并编写第一、十一章,由续大我教授编写第二、三、八、十章,由庞沁华教授编写四、五、六章,由吴伟陵教授编写第七、九章,最后全书由周炯槃、庞沁华统编定稿\n
#
# 　　鉴于首次正式出版,难免有不妥之处,敬请指正\n
#
# 周炯桑
#
# 第1章绪论1
#
# 1.1引言1
#
# 1.2通信发展简史和展望2
#
# 1.3通信系统和通信网的构成5
#
# 　　1.3.1概述5
#
# 　　1.3.2信源、信宿和信号6
#
# 　　1.3.3信源编译码设备6
#
# 　　1.3.4信道及信道编译码设备6
#
# 1.4本书的总体结构7
#
# 第2章确定信号分析9
#
# ...

# %%
# 在output目录下有一个文件是通信原理全部无前后修.txt

# 正常结构化的形式是{"knowledge_points": [{"title": "", "description": ""},{"title": "", "description": ""}, ...],"relations": [{"source": "", "target": "", "type": ""}, {"source": "", "target": "", "type": ""}, ...]}

# 我现在需要检测所有格式是否正确
import json
with open(r"../output/通信原理全部无前后修.txt", 'r', encoding='utf-8') as f:
    content_lines = f.readlines()
    print(len(content_lines))
    for i in content_lines:
        try:
            json.loads(i)
        except:
            print(i)
# Out:
# 10448
# ﻿{
#
#     "knowledge_points": [
#
#         {"title": "通信系统", "en": "Communication system"},
#
#         {"title": "通信网", "en": "Communication network"},
#
#         {"title": "信号分析", "en": "Signal analysis"},
#
#         {"title": "随机过程", "en": "Random process"},
#
#         {"title": "模拟通信系统", "en": "Analog communication system"},
#
#         {"title": "数字信号", "en": "Digital signal"},
#
#         {"title": "信源编码", "en": "Source coding"},
#
#         {"title": "信道", "en": "Channel"},
#
#         {"title": "信道编码", "en": "Channel coding"},
#
#         {"title": "扩频通信", "en": "Spread spectrum communication"},
#
#         {"title": "正交频分复用多载波调制技术", "en": "Orthogonal frequency division multiplexing (OFDM)"},
#
#         {"title": "通信系统优化", "en": "Communication system optimization"},
#
#     ],
#
#     "relations": [
#
#         {"source": "通信系统", "target": "通信网", "type": "包含"},
#
#         {"source": "信号分析", "target": "模拟通信系统", "type": "应用于"},
#
# ...

# %%
i=1
for line in lines:
    print(i/len(lines))
    response = completion_with_backoff(
        # model="text-davinci-003",
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": system_content},
            {"role": "user", "content": line},
        ],
        top_p=0.1,
        frequency_penalty=0,
        presence_penalty=0
    )
    if int(response['usage']['total_tokens'])<4096:
        completion = response['choices'][0]["message"]["content"]
        with open("../output/通信原理无前后修.txt", 'a', encoding="utf-8-sig") as f:
            f.write(completion)
    else:
        print("超过4096了")        
        temp_lines= line.split("\n")
        length=len(temp_lines)
        temp_line1=''
        temp_line2=''
        index1=0
        for i in temp_lines:
            if index1 < int(length/2):
                temp_line1=temp_line1+'\n'+i
            else:
                temp_line2=temp_line2+'\n'+i
            index1+=1
        response = completion_with_backoff(
            # model="text-davinci-003",
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": temp_line1},
            ],
            top_p=0.1,
            frequency_penalty=0,
            presence_penalty=0
        )
        completion = response['choices'][0]["message"]["content"]
        with open("../output/通信原理无前后修.txt", 'a', encoding="utf-8-sig") as f:
            f.write(completion)
        response = completion_with_backoff(
            # model="text-davinci-003",
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": temp_line2},
            ],
            top_p=0.1,
            frequency_penalty=0,
            presence_penalty=0
        )
        completion = response['choices'][0]["message"]["content"]
        with open("../output/通信原理无前后修.txt", 'a', encoding="utf-8-sig") as f:
            f.write(completion)
    # print(f"completion:{completion}")
    i+=1
# Out:
# 0.02564102564102564
# 0.05128205128205128
# 0.07692307692307693
# 0.10256410256410256
# 0.1282051282051282
# 0.15384615384615385
# 0.1794871794871795
# 0.20512820512820512
# 0.23076923076923078
# 0.2564102564102564
# 0.28205128205128205
# 0.3076923076923077
# 0.3333333333333333
# 0.358974358974359
# 0.38461538461538464
# 0.41025641025641024
# 0.4358974358974359
# 0.46153846153846156
# 0.48717948717948717
# 0.5128205128205128
# 0.5384615384615384
# 0.5641025641025641
# 0.5897435897435898
# 0.6153846153846154
# 0.6410256410256411
# 0.6666666666666666
# 0.6923076923076923
# 0.717948717948718
# 0.7435897435897436
# 0.7692307692307693
# 0.7948717948717948
# 0.8205128205128205
# 0.8461538461538461
# 0.8717948717948718
# 0.8974358974358975
# 0.9230769230769231
# 0.9487179487179487
# 0.9743589743589743
# 1.0

# %%
print(lines[2])
# Out:
# 　7.4互信息I(X；Y)215
#
# 　7.5无失真离散信源编码定理简介216
#
# 　7.6无失真离散信源编码219
#
# 　7.7信息率失真R(D)函数221
#
# 　7.8限失真信源编码定理与限失真信源编码225
#
# 　7.9连续信源的限失真编码226
#
# 　　7.9.1模拟信号数字化基本原理226
#
# 　　7.9.2采样228
#
# 　　7.9.3标量量化233
#
# 　　7.9.4脉冲编码调制239
#
# 　　7.9.5时分复用241
#
# 　　7.9.6矢量量化242
#
# 　7.10有记忆信源解除相关性的限失真信源编码245
#
# 　　7.10.1预测编码245
#
# 　　7.10.2变换编码250
#
# 　习题260
#
# 第8章信道263
#
# 　8.1引言263
#
# 　8.2信道的定义和分类263
#
# 　8.3通信信道实例264
#
# 　　8.3.1恒参信道264
#
# 　　8.3.2随参信道265
#
# 　8.4信道的数学模型266
#
# 　　8.4.1连续信道模型266
#
# 　　8.4.2离散信道模型267
#
# 　8.5无失真信道268
#
# 　8.6衰落信道269
#
# 　　8.6.1衰落信道的数学模型269
#
# 　　8.6.2时变平衰落信道269
#
# 　　8.6.3时不变频率选择性衰落信道270
#
# 　8.7分集271
#
# 　8.8信道容量272
#
# 　习题273
#
# 第9章信道编码276
#
# 　9.1信道编码的基本概念276
#
# 　9.2线性分组码282
#
# 　　9.2.1基本概念282
#
# 　　9.2.2生成矩阵和监督矩阵283
#
# 　　9.2.3对偶码288
#
# 　　9.2.4系统码的编码与译码289
#
# 　　9.2.5汉明码291
#
# 　9.3循环码292
#
# 　　9.3.1基本概念292
#
# 　　9.3.2多项式描述294
#
# 　　9.3.3生成多项式与生成矩阵296
#
# 　　9.3.4编码电路301
#
# 　　9.3.5循环冗余校验302
#
# 　9.4BCH码与RS码304
#
# 　9.5卷积码308
#
# 　　9.5.1卷积码的编码309
#
# ...

# %%
def generate_text(prompt):
    response = completion_with_backoff(
      model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": lines[2]},
            ],
            top_p=0.1,
            frequency_penalty=0,
            presence_penalty=0
    )
    # return response['choices'][0]["message"]["content"]
    return response

prompt = "what the meaning of Concept prerequisite relations?"

response = generate_text(prompt)    
print(response['choices'][0]["message"]["content"]) 
# print(generate_text(prompt))
# Out:
# {
#   "knowledge_points": [
#     {"title": "互信息", "en": "Mutual Information"},
#     {"title": "无失真离散信源编码定理", "en": "Lossless Discrete Source Coding Theorem"},
#     {"title": "无失真离散信源编码", "en": "Lossless Discrete Source Coding"},
#     {"title": "信息率失真函数", "en": "Rate-Distortion Function"},
#     {"title": "限失真信源编码定理", "en": "Lossy Source Coding Theorem"},
#     {"title": "连续信源的限失真编码", "en": "Lossy Source Coding for Continuous Sources"},
#     {"title": "模拟信号数字化基本原理", "en": "Basic Principles of Analog Signal Digitization"},
#     {"title": "采样", "en": "Sampling"},
#     {"title": "标量量化", "en": "Scalar Quantization"},
#     {"title": "脉冲编码调制", "en": "Pulse Code Modulation"},
#     {"title": "时分复用", "en": "Time Division Multiplexing"},
#     {"title": "矢量量化", "en": "Vector Quantization"},
#     {"title": "有记忆信源解除相关性的限失真信源编码", "en": "Lossy Source Coding for Correlated Sources"},
#     {"title": "预测编码", "en": "Predictive Coding"},
#     {"title": "变换编码", "en": "Transform Coding"},
# ...

# %%
print(response['usage']['total_tokens'])
# Out:
# 4097

# %%
openai.api_key = "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"


coursename = "通信原理"

system_content = '''You are a helpful assistant that 
                 extract knowledge points and relations between knowledge points from contents below, 
                 returning in the form of json. 
                 the value of "description" should be the definition or explaination of the "title".
                 the value of "type" should represent professional relationship between "source" to "target" in 'Communication Theory' area.
                 all values are better to be in Chinese.
                 {
                    "knowledge_points": [{"title": "", "description": ""},{"title": "", "description": ""}, ...],
                    "relations": [{"source": "", "target": "", "type": ""}, {"source": "", "target": "", "type": ""}, ...]
                 }
                 '''
user_content = ""

print(os.path.abspath(os.curdir))
with open("通信原理.txt", 'r', encoding='utf-8') as f:
    content_lines = f.readlines()
    # print(content_lines)


@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(6))
def completion_with_backoff(**kwargs):
    return openai.ChatCompletion.create(**kwargs)

content = ""
count_line = 0
# i = 239 #到4530了
i = 0
while i < len(content_lines):
    # print(content_lines[i])
    content += content_lines[i]
    i += 1
    count_line += 1
    print(f"i:{i}, count_line:{count_line}")
    if count_line % 9 == 0:
        response = completion_with_backoff(
            # model="text-davinci-003",
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": content},
            ],
            top_p=0.1,
            frequency_penalty=0,
            presence_penalty=0
        )
        completion = response['choices'][0]["message"]["content"]
        with open("生成文档/通信原理.txt", 'a', encoding="utf-8-sig") as f:
            f.write(completion)
        print(f"completion:{completion}")
        i -= 2
        content = ""
        count_line = 0
        continue
    elif i == len(content_lines) : #最后一行
        response = completion_with_backoff(
            # model="text-davinci-003",
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": content},
            ],
            top_p=0.1,
            frequency_penalty=0,
            presence_penalty=0
        )
        completion = response['choices'][0]["message"]["content"]
        with open("生成文档/通信原理.txt", 'a', encoding="utf-8-sig") as f:
            f.write(completion)
            print(f"completion:{completion}")
